# %% [markdown]
# a. far inserire all'utente due valori interi

# %%
numero1 = int(input("inserire numero 1 ="))
numero2 = int(input("inserire numero 2 ="))
# Out:
# inserire numero 1 = 10
# inserire numero 2 = 2

# %% [markdown]
#  b. effettuare le 4 operazioni aritmetiche tra i due numeri

# %%
print (numero1, "+",numero2,"=", str(numero1+numero2))
print (numero1, "-",numero2,"=", str(numero1-numero2))
print (numero1, "/",numero2,"=", str(numero1/numero2))
print (numero1, "*",numero2,"=", str(numero1*numero2))
# Out:
# 10 + 2 = 12
# 10 - 2 = 8
# 10 / 2 = 5.0
# 10 * 2 = 20

# %% [markdown]
#  c.
# effettuare l'elevamento a potenza del primo numero per il secondo

# %%
print("potenza =" +str(pow(numero1,numero2)))
# Out:
# potenza =100

# %% [markdown]
# d. effettuare il calcolo del resto della divisione tra il primo e il secondo numero

# %%
print("resto =" +str(numero1 % numero2))
# Out:
# resto =0

# %% [markdown]
# f. effettuare la divisione intera tra il primo e il secondo numero

# %%
print ("int div = " +str(numero1 // numero2))
# Out:
# int div = 5

# %% [markdown]
# g. incrementare di una unità entrambi i numeri

# %%
numero1+= 1
numero2+= 1

print ("numero1 + 1 =" +str(numero1 + 1))
print ("numero2 + 1 =" +str(numero2 + 1))
# Out:
# numero1 + 1 =12
# numero2 + 1 =4

# %% [markdown]
# h. far inserie all'utente due valori: il primo rappresenta la sua altezza (in metri) e il secondo rappresenta il suo peso (in kg). Visualizzare poi l'IMC (google it...)

# %%
val1 = float(input("inserire la propria altezza in metri ="))
val2 = float(input("inserire il proprio peso in kg ="))
# Out:
# inserire la propria altezza in metri =1.79
# inserire il proprio peso in kg =80

# %% [markdown]
# i. arrotondare l'IMC precedente

# %%
imc = round(25,9)
print(imc)
# Out:
# 25

# %% [markdown]
# j. visualizzare il proprio nome, cognome, data di nascita e città di nascita separando le informazioni con un trattino

# %%
nome = str(input("nome = "))  
cognome = str(input("  cognome = "))
datadinascita = str(input(" data di nascita = "))
cittàdinascita = str(input(" città di nascita ="))
# Out:
# nome = Gabriele
#   cognome = Di Lecce
#  data di nascita = 03/03/2005
#  città di nascita = Milano

# %% [markdown]
# k. visualizzare le stesse informazioni per 10 volte di seguito

# %%
informazioni = (nome, cognome, datadinascita, cittàdinascita)
print(informazioni * 10)
# Out:
# ('Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano', 'Gabriele', 'Di Lecce', '03/03/2005', ' Milano')

# %% [markdown]
# l. assegnare il proprio nome e cognome ad una stringa e visualizzarla con tutte le lettere maiuscole

# %%
string = "gabriele di lecce"



print(string.upper())
# Out:
# GABRIELE DI LECCE

# %% [markdown]
# m. assegnare il proprio nome e cognome ad una stringa e visualizzarla con le prime lettere maiuscole

# %%
string = "gabriele di lecce."

print(string.title())
# Out:
# Gabriele Di Lecce.

# %% [markdown]
# n. assegnare il proprio nome e cognome ad una stringa e visualizzarne la lunghezza

# %%
string = "Gabriele Di Lecce"

lunghezza = len(string)

print(lunghezza)
# Out:
# 17

# %% [markdown]
# o. assegnare il proprio nome e cognome ad una stringa e contate quante vocali contiene

# %%
string="Gabriele Di Lecce"
contatore=0
vocali= set('aeiou')
for lettera in string.lower(): 
    if lettera in vocali:contatore=contatore+1
print(contatore)
# Out:
# 7

# %% [markdown]
# p. assegnare il proprio nome e cognome ad una stringa e visualizzare i primi 5 caratteri

# %%
string = "Gabriele Di Lecce"
print(string[0:5])
# Out:
# Gabri

# %% [markdown]
# q. assegnare il proprio nome e cognome ad una stringa e visualizzare gli ultimi 5 caratteri

# %%
print(string[12:17])
# Out:
# Lecce

# %% [markdown]
# r.. assegnare il proprio nome e cognome ad una stringa e visualizzare i 5 caratteri centrali

# %%
print(string[6:11])
# Out:
# le Di

# %% [markdown]
# s. assegnare il proprio nome e cognome ad una stringa e sostituire le vocali con una X

# %%
s = "Gabriele Di Lecce"
sX=s.replace('a','X').replace('e','X').replace('i','X').replace('o','X')


print(sX,)
# Out:
# GXbrXXlX DX LXccX
