# %% [markdown]
# 1. scrivere una funzione chiamata media che dati due numeri restituisca la media. Utilizzare poi la funzione in un programma che acquisisca dall'utente due numeri e calcoli la media

# %%
def media(x,y):
  z = (x + y) / 2

  return z
media(int(input("inserire il primo numero")), int(input("inserire il secondo numero")))
# Out:
# inserire il primo numero 10
# inserire il secondo numero2
# 6.0

# %% [markdown]
# 2. scrivere una funzione chiamata piuCorta che date due liste restituisca la lista con meno elementi. Utilizzare poi la funzione in un programma che acquisisca dall'utente due liste e visualizzi gli elementi della lista più corta.

# %%
def piuCorta(list1,list2):
  if len(list1) > len(list2):
    return list2
  else:
    return list1

l1 = [1,2,3,4,5]
l2 = [3,4,5]
print('la lista più corta è' + str(piuCorta(l1,l2)))
l3 = [3,4] 
print('la lista più corta è' + str(piuCorta(l1,l3)))
print('la lista più corta è' + str(piuCorta(l2,l3)))
# Out:
# la lista più corta è[3, 4, 5]
# la lista più corta è[3, 4]
# la lista più corta è[3, 4]

# %% [markdown]
# scrivere un programmma che date 3 liste visualizzi la più corta. Utilizzare lafunzione piuCorta2

# %%
 numeri1 = [int(s) for s in input("inserisci i valori: ").split()]
numeri2 = [int(s) for s in input("inserisci i valori: ").split()]
numeri3 = [int(s) for s in input("inserisci i valori: ").split()]
print(piuCorta(piuCorta(numeri1,numeri2),numeri3))
# Out:
# inserisci i valori: 1 2
# inserisci i valori: 1 2 3 4
# inserisci i valori: 1  2 3
# [1, 2]

# %% [markdown]
# 3. scrivere una funzione chiamata costruisciLista che dati due numeri interi restituisca la lista formata da tutti i numeri interi compresi tra i due numeri dati. Utilizzare poi la funzione in un programma che acquisisca dall'utente due numeri e visualizzi la lista formata da tutti i numeri interi compresi tra i due numeri dati ma a partire dal più grande fino al più piccolo.

# %%
def costruisciLista (x,y):
  a = min(x,y)
  b = max(x,y)
  z = [i for i in range(a,b + 1)]
  return z
lista = costruisciLista(int(input("inserire il primo numero")), int(input("inserire il secondo numero")))
lista.reverse()
print(lista)
# Out:
# inserire il primo numero 2
# inserire il secondo numero 10
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# 4. scrivere una funzione chiamata valoreAssoluto che dato un numero restituisca il suo valore assoluto. Utilizzare poi questa funzione per determinare il valore assoluto degli elementi di una lista inserita dall'utente.

# %%
arr = input('inserisci la prima lista:').split(',')

def valore_assoluto(n):
  return abs(n)

print([valore_assoluto(int(i)) for i in arr ])
# Out:
# inserisci la prima lista:10, -300
# [10, 300]

# %% [markdown]
# 5. scrivere una funzione chiamata scambia che data una lista scambi il primo elemento con l'ultimo, il secondo con il penultimo e così via. Utilizzare poi la funzione in un programma che acquisisca dall'utente una lista di 10 elementi e li visualizzi scambiati.

# %%
def scambia(lista): # lista è il parametro formale
  
  lista.reverse()
  return lista

elementi1 = [((input("inserisci l'elemento ")))for i in range(0,4)]
elementi2 = [((input("inserisci l'elemento ")))for i in range(0,4)]

print(scambia(elementi1)) # elementi1 è il parametro attuale

print(scambia(elementi2)) # elementi2 è un altro parametro attuale
# Out:
# inserisci l'elemento 1
# inserisci l'elemento 2
# inserisci l'elemento 3
# inserisci l'elemento 4
# inserisci l'elemento 5
# inserisci l'elemento 0
# inserisci l'elemento 6
# inserisci l'elemento 7
# ['4', '3', '2', '1']
# ['7', '6', '0', '5']

# %% [markdown]
# 6. scrivere una funzione lambda che dati due numeri calcoli la loro somma. Utilizzare la funzione in un programma che chieda all'utente due numeri interi e visualizzi la loro somma.

# %%
lam1 = lambda x,y: x + y

lam1(int(input(' ')), int(input(' ')))
# Out:
#  10
#  11
# 21

# %% [markdown]
# 7. scrivere un programma che utilizzi una lambda function per aumentare di 10 unità tutti gli elementi di una lista di interi inserita dall'utente.

# %%
listaelementi = [int(input("inserisci l'elemento: "))for i in range(0,4)]
list(map(lambda x: x + 10, listaelementi )) #map è una funziona che applica (ad ogni elemento di una lista) una funzione
# Out:
# inserisci l'elemento: 10
# inserisci l'elemento: 12
# inserisci l'elemento: 14
# inserisci l'elemento: 16
# [20, 22, 24, 26]

# %% [markdown]
# 8. scrivere una funzione lambda che sostituisca il valore 0 se il parametro è negativo, il valore del parametro se è positivo. Utilizzare poi la funzione in un programma che chieda all'utente i 10 elementi di una lista e visualizzi la lista con il valore 0 al posto dei numeri negativi.

# %%
lista1 = [int(input("inserisci l'elemento: "))for i in range(0,10-)]
for i in range(len(lista1)):
  if lista1[i] < 0:
    a = lambda l: l * 0
    lista1[i] = a(lista1[i])

 

print(lista1)
# Out:
# inserisci l'elemento: 10
# inserisci l'elemento: 20
# inserisci l'elemento: 30
# inserisci l'elemento: -40
# inserisci l'elemento: 50
# inserisci l'elemento: -60
# inserisci l'elemento: 70
# inserisci l'elemento: -80
# inserisci l'elemento: 90
# inserisci l'elemento: -100
# [10, 20, 30, 0, 50, 0, 70, 0, 90, 0]

# %%
def sost(valore):
  if valore < 0:
    return 0
  else:
    return valore

l = [ int(input("inserisci l'elemento: "))for i in range(0,4)]
l2 = [sost(elemento) for elemento in l ]


sost2 = lambda x: x if x >= 0 else 0
l3 = [sost2(elemento) for elemento in l]

print(l)
print(l2)
print(l3)
# Out:
# inserisci l'elemento: 1
# inserisci l'elemento: 2
# inserisci l'elemento: -5
# inserisci l'elemento: -7
# [1, 2, 0, 0]
# [1, 2, -5, -7]
# [1, 2, 0, 0]

# %% [markdown]
# 9. scrivere un programma che calcoli il fattoriale di un numero utilizzando una lambda function. Provare a realizzare una lambda function ricorsiva (per la ricorsione, google it...)

# %%
fattoriale = lambda n: 1 if n == 0 else n * fattoriale(n - 1)
fattoriale(968)
# Out:
# ...
