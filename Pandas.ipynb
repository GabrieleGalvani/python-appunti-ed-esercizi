# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/CappuCitti/Python-appunti-ed-esercizi/main/Pandas/Data/pokemon_list.csv'

df = pd.read_csv(url)
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2    Ivysaur  Grass  Poison  ...       80     60           1      False
#
# [2 rows x 12 columns]

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [3 rows x 12 columns]

# %%
df[['Name','Type 1','Type 2']].head(5)
# Out:
#                     Name Type 1  Type 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN

# %%
df.iloc[[1,2,3]]
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [3 rows x 12 columns]

# %%
df.iloc[:,[1,2,4]]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
[df['Type 1'] == 'Water']
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  795    False
#  796    False
#  797    False
#  798    False
#  799    False
#  Name: Type 1, Length: 800, dtype: bool]

# %%
df.loc[df['Type 1'] == 'Fairy']
# Out:
#        #        Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 40    35    Clefairy  Fairy     NaN  ...       65     35           1      False
# 41    36    Clefable  Fairy     NaN  ...       90     60           1      False
# 187  173      Cleffa  Fairy     NaN  ...       55     15           2      False
# 189  175      Togepi  Fairy     NaN  ...       65     20           2      False
# 190  176     Togetic  Fairy  Flying  ...      105     40           2      False
# 225  209    Snubbull  Fairy     NaN  ...       40     30           2      False
# 226  210    Granbull  Fairy     NaN  ...       60     45           2      False
# 519  468    Togekiss  Fairy  Flying  ...      115     80           4      False
# 737  669     Flabébé  Fairy     NaN  ...       79     42           6      False
# 738  670     Floette  Fairy     NaN  ...       98     52           6      False
# 739  671     Florges  Fairy     NaN  ...      154     75           6      False
# 752  682    Spritzee  Fairy     NaN  ...       65     23           6      False
# 753  683  Aromatisse  Fairy     NaN  ...       89     29           6      False
# 754  684     Swirlix  Fairy     NaN  ...       57     49           6      False
# 755  685    Slurpuff  Fairy     NaN  ...       75     72           6      False
# 770  700     Sylveon  Fairy     NaN  ...      130     60           6      False
# 792  716     Xerneas  Fairy     NaN  ...       98     99           6       True
#
# [17 rows x 12 columns]

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Speed'] >= 100)]
# Out:
#        #                       Name Type 1  ... Speed  Generation  Legendary
# 6      6                  Charizard   Fire  ...   100           1      False
# 7      6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 43    38                  Ninetales   Fire  ...   100           1      False
# 84    78                   Rapidash   Fire  ...   105           1      False
# 171  157                 Typhlosion   Fire  ...   100           2      False
# 263  244                      Entei   Fire  ...   100           2       True
# 279  257      BlazikenMega Blaziken   Fire  ...   100           3      False
# 437  392                  Infernape   Fire  ...   108           4      False
# 573  514                   Simisear   Fire  ...   101           5      False
# 723  655                    Delphox   Fire  ...   104           6      False
# 731  663                 Talonflame   Fire  ...   126           6      False
# 736  668                     Pyroar   Fire  ...   106           6      False
#
# [13 rows x 12 columns]

# %%
df.loc[15:21,['Type 1','Speed']]
# Out:
#     Type 1  Speed
# 15     Bug     70
# 16     Bug     50
# 17     Bug     35
# 18     Bug     75
# 19     Bug    145
# 20  Normal     56
# 21  Normal     71

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 794  718         Zygarde50% Forme   Dragon  ...    95           6       True
# 695  634                 Zweilous     Dark  ...    58           5      False
# 46    41                    Zubat   Poison  ...    55           1      False
# 631  570                    Zorua     Dark  ...    65           5      False
# 632  571                  Zoroark     Dark  ...   105           5      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 393  359          AbsolMega Absol     Dark  ...   115           3      False
# 392  359                    Absol     Dark  ...    75           3      False
# 68    63                     Abra  Psychic  ...    90           1      False
# 511  460  AbomasnowMega Abomasnow    Grass  ...    30           4      False
# 510  460                Abomasnow    Grass  ...    60           4      False
#
# [800 rows x 12 columns]

# %%
df.sort_values(['Type 1', 'Type 2'], ascending=False) #oppure df.sort_values(['Type 1', 'Type 2'], ascending=[1,0])
# Out:
#        #        Name Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 440  395    Empoleon  Water  Steel  ...      101     60           4      False
# 240  222     Corsola  Water   Rock  ...       85     35           2      False
# 404  369   Relicanth  Water   Rock  ...       65     55           3      False
# 625  564    Tirtouga  Water   Rock  ...       45     22           5      False
# 626  565  Carracosta  Water   Rock  ...       65     32           5      False
# ..   ...         ...    ...    ...  ...      ...    ...         ...        ...
# 649  588  Karrablast    Bug    NaN  ...       45     60           5      False
# 677  616     Shelmet    Bug    NaN  ...       65     25           5      False
# 678  617    Accelgor    Bug    NaN  ...       60    145           5      False
# 732  664  Scatterbug    Bug    NaN  ...       25     35           6      False
# 733  665      Spewpa    Bug    NaN  ...       30     29           6      False
#
# [800 rows x 12 columns]

# %%
df['Differenza'] = df['Attack'] - df['Defense']
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Differenza
# 0      1              Bulbasaur    Grass  ...          1      False           0
# 1      2                Ivysaur    Grass  ...          1      False          -1
# 2      3               Venusaur    Grass  ...          1      False          -1
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False         -23
# 4      4             Charmander     Fire  ...          1      False           9
# ..   ...                    ...      ...  ...        ...        ...         ...
# 795  719                Diancie     Rock  ...          6       True         -50
# 796  719    DiancieMega Diancie     Rock  ...          6       True          50
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True          50
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True         100
# 799  721              Volcanion     Fire  ...          6       True         -10
#
# [800 rows x 13 columns]

# %%
# %%time
df['Differenza'] = df['Attack'] - df['Defense']
# Out:
# CPU times: user 1.39 ms, sys: 0 ns, total: 1.39 ms
# Wall time: 1.51 ms

# %%
df = df.drop(columns='Differenza') #df = df.drop(columns=['Attack','Defense']) oppure df = df.drop([3.4])
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df.to_excel('./file.xlsx')
df.to_csv('./file.csv')
df.to_json('./file.json')

# %%
df.groupby('month')
