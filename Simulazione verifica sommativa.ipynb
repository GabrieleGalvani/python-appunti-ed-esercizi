# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
url = 'https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/punti-somministrazione-latest.csv'
df = pd.read_csv(url)
df
#spessore = width
# Out:
#     area provincia  ... codice_regione_ISTAT nome_area
# 0    ABR    CHIETI  ...                   13   Abruzzo
# 1    ABR    CHIETI  ...                   13   Abruzzo
# 2    ABR    CHIETI  ...                   13   Abruzzo
# 3    ABR  L'AQUILA  ...                   13   Abruzzo
# 4    ABR  L'AQUILA  ...                   13   Abruzzo
# ..   ...       ...  ...                  ...       ...
# 288  VEN    ROVIGO  ...                    5    Veneto
# 289  VEN   TREVISO  ...                    5    Veneto
# 290  VEN   VENEZIA  ...                    5    Veneto
# 291  VEN    VERONA  ...                    5    Veneto
# 292  VEN   VICENZA  ...                    5    Veneto
#
# [293 rows x 8 columns]

# %%
url1 = 'https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/platea.csv'
df1 = pd.read_csv(url1)
df1
# Out:
#     area nome_area fascia_anagrafica  totale_popolazione
# 0    ABR   Abruzzo             12-19               94727
# 1    ABR   Abruzzo             20-29              125230
# 2    ABR   Abruzzo             30-39              146965
# 3    ABR   Abruzzo             40-49              187162
# 4    ABR   Abruzzo             50-59              208686
# ..   ...       ...               ...                 ...
# 163  VEN    Veneto             40-49              715790
# 164  VEN    Veneto             50-59              806474
# 165  VEN    Veneto             60-69              610635
# 166  VEN    Veneto             70-79              494721
# 167  VEN    Veneto               80+              370529
#
# [168 rows x 4 columns]

# %%
fig = plt.figure()
ax = plt.axes()
